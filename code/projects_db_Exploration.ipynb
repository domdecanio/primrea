# %%
import pandas as pd

path_root = "C:/Users/deca761/OneDrive - PNNL/Documents/"
path_data = "work items/projects db/"

# %%
devices = pd.read_csv(f'{path_root}{path_data}devices.csv')
organizations = pd.read_csv(f'{path_root}{path_data}organizations.csv')
projects = pd.read_csv(f'{path_root}{path_data}projects.csv')
test_sites = pd.read_csv(f'{path_root}{path_data}test_sites.csv')

# %%
devices
# Out:
#                                                   Name  \
# 0    PRIMRE/Databases/Projects Database/Devices/40 ...
# 1    PRIMRE/Databases/Projects Database/Devices/650...
# 2    PRIMRE/Databases/Projects Database/Devices/AMO...
# 3    PRIMRE/Databases/Projects Database/Devices/AND...
# 4    PRIMRE/Databases/Projects Database/Devices/AND...
# ..                                                 ...
# 326  PRIMRE/Databases/Projects Database/Devices/Wel...
# 327   PRIMRE/Databases/Projects Database/Devices/XCT-1
# 328  PRIMRE/Databases/Projects Database/Devices/Yon...
# 329  PRIMRE/Databases/Projects Database/Devices/You...
# 330  PRIMRE/Databases/Projects Database/Devices/Zho...
#
#                                                Website  Description  \
# 0                                                  NaN          NaN
# 1    https://iopscience.iop.org/article/10.1088/175...          NaN
# 2    https://www.amog.consulting/renewable-energy/a...          NaN
# ...

# %%
organizations
# Out:
#                              Name                                  Type  \
# 0                 40 South Energy                  Technology Developer
# 1              48 North Solutions                                   NaN
# 2      4c Engineering Consultancy  Project Manager,Technology Developer
# 3                   ANDRITZ Hydro                  Technology Developer
# 4                 ATA Engineering                  Technology Developer
# ..                            ...                                   ...
# 415               Wedge Global SL  Project Manager,Technology Developer
# 416                      Wello Oy                  Technology Developer
# 417                        Weptos                  Technology Developer
# 418  Yourbrook Energy Systems Ltd                  Technology Developer
# 419           Zhejiang University                 Academic Institutions
#
#                                         Sector         Country  Year Founded  \
# ...

# %%
len(devices['Technology Developer'].unique())
# Out:
# 260
