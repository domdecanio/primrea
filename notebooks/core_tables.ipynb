# %% [markdown]
# # Core Tables

# %% [markdown]
# The purpose of this notebook is to develop the tables for MHKDR, Tethys, and Tethys Engineering which will contain the entry-level data for these Knowledge hubs. I may need to further divide this development by knowledge hub, as there will most likely be partial overlap between the fields of the Tethys and MHKDR.

# %% [markdown]
# ### Setup

# %%
import requests
import pandas as pd
import primrea.kh_table_gen.entry_based as entry_based_table_gen

# %% [markdown]
# ### Dev

# %%
#tethys_dataframe[tethys_dataframe['originationDate']]
tethys_dataframe['originationDate'][0]
# Out:
# '2017-09-29'

# %%
#tethys_dataframe['originationDate2']=tethys_dataframe.apply(tethys_dataframe['originationDate'])

# %%
tethys_dataframe['originationDate']
# Out:
# 0       2017-09-29
# 1       2016-02-09
# 2       2020-01-10
# 3       2020-03-01
# 4       2018-02-14
#            ...
# 4238    2024-05-01
# 4239    2024-07-01
# 4240    2024-05-06
# 4241    2024-05-16
# 4242    2024-04-01
# Name: originationDate, Length: 4243, dtype: object

# %%
year_lst = list()
month_lst = list()
day_lst = list()
for i in range(0, len(tethys_dataframe['originationDate'])):
    year = int(tethys_dataframe['originationDate'][i][:4])
    month = int(tethys_dataframe['originationDate'][i][5:7])
    day = int(tethys_dataframe['originationDate'][i][8:])
    year_lst.append(year)
    month_lst.append(month)
    day_lst.append(day)

# %%
tethys_dataframe['originationDate'][0][:4]
# Out:
# '2017'

# %%
year_lst[:30]
# Out:
# [2017,
#  2016,
#  2020,
#  2020,
#  2018,
#  2018,
#  2019,
#  2016,
#  2015,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2019,
#  2018,
#  2019,
#  2019,
#  2018,
#  2018,
#  2016,
#  2017,
#  2015,
#  2014,
#  2019,
#  2019,
#  2019,
#  2019]

# %%
tethys_dataframe['originationDate2'] = tethys_dataframe[tethys_dataframe['originationDate'].to_datetime()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21456\3656942201.py in ?()
# ----> 1 tethys_dataframe['originationDate2'] = tethys_dataframe[tethys_dataframe['originationDate'].to_datetime()]
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    5903             and name not in self._accessors
#    5904             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905         ):
#    5906             return self[name]
# -> 5907         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
tethys_dataframe['originationDate'].to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21456\1452279744.py in ?()
# ----> 1 tethys_dataframe['originationDate'].to_datetime()
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    5903             and name not in self._accessors
#    5904             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905         ):
#    5906             return self[name]
# -> 5907         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
banana = pd.to_datetime(tethys_dataframe['originationDate'])

# %%
tethys_dataframe['originationDate2'] = banana

# %%
tethys_dataframe
# Out:
#                                        URI  \
# 0         https://tethys.pnnl.gov/node/499
# 1         https://tethys.pnnl.gov/node/500
# 2         https://tethys.pnnl.gov/node/501
# 3         https://tethys.pnnl.gov/node/502
# 4         https://tethys.pnnl.gov/node/503
# ...                                    ...
# 4238  https://tethys.pnnl.gov/node/2078945
# 4239  https://tethys.pnnl.gov/node/2078958
# 4240  https://tethys.pnnl.gov/node/2078959
# 4241  https://tethys.pnnl.gov/node/2078965
# 4242  https://tethys.pnnl.gov/node/2078973
#
#                                       type  \
# 0     [Document, Document/Journal Article]
# 1              [Document, Document/Report]
# 2     [Document, Document/Journal Article]
# 3     [Document, Document/Journal Article]
# 4              [Document, Document/Report]
# ...                                    ...
# 4238  [Document, Document/Journal Article]
# 4239  [Document, Document/Journal Article]
# 4240  [Document, Document/Journal Article]
# 4241  [Document, Document/Journal Article]
# 4242           [Document, Document/Report]
#
#                                             landingPage  \
# 0     https://tethys.pnnl.gov/publications/marine-re...
# 1     https://tethys.pnnl.gov/publications/port-fair...
# 2     https://tethys.pnnl.gov/publications/baseline-...
# 3     https://tethys.pnnl.gov/publications/assessing...
# 4     https://tethys.pnnl.gov/publications/wave-ener...
# ...                                                 ...
# 4238  https://tethys.pnnl.gov/publications/localized...
# 4239  https://tethys.pnnl.gov/publications/potential...
# 4240  https://tethys.pnnl.gov/publications/elevated-...
# 4241  https://tethys.pnnl.gov/publications/environme...
# 4242  https://tethys.pnnl.gov/publications/cultural-...
#
#                                               sourceURL  \
# 0         https://www.mdpi.com/1996-1073/10/10/1512/htm
# 1                            http://bps.energy/projects
# 2     https://www.sciencedirect.com/science/article/...
# 3     https://www.sciencedirect.com/science/article/...
# 4     https://publications.csiro.au/rpr/pub?pid=csir...
# ...                                                 ...
# 4238  https://agupubs.onlinelibrary.wiley.com/doi/fu...
# 4239  https://www.sciencedirect.com/science/article/...
# 4240  https://journals.plos.org/plosone/article?id=1...
# 4241  https://iopscience.iop.org/article/10.1088/174...
# 4242  https://blueeconomycrc.com.au/project/cultural...
#
#                                                   title  \
# 0     Marine Renewable Energy in the Mediterranean S...
# 1     The Port Fairy Pilot Wave Energy Project Envir...
# 2     Baseline assessment of underwater noise in the...
# 3     Assessing the consistency of in-stream tidal e...
# 4     Wave Energy Deployments Physical Impact Guidel...
# ...                                                 ...
# 4238  Localized Tidal Energy Extraction in Puget Sou...
# 4239  Potential environmental impacts of floating so...
# 4240  Elevated fish densities extend kilometres from...
# 4241  Environmental impacts from large scale offshor...
# 4242  Cultural Licence to Operate in the Blue Econom...
#
#                                             description  \
# 0     In this work, an extended overview of the mari...
# 1     This Environmental Management Plan (EMP) detai...
# 2     The Ria Formosa is a sheltered large coastal l...
# 3     The provincial government of Nova Scotia, Cana...
# 4     Australia’s wave energy resource has been asse...
# ...                                                 ...
# 4238  Harvesting energy via tidal stream turbines is...
# 4239  The use of floating photovoltaic systems in fr...
# 4240  Thousands of offshore oil and gas platforms ha...
# 4241  The urgency to mitigate the effects of climate...
# 4242  In an era of heightened awareness of environme...
#
#                                                  author  \
# 0     [Soukissian, T., Denaxa, D., Karathanasi, F., ...
# 1                                    [BioPower Systems]
# 2     [Soares, C., Pacheco, A., Zabel, F., González-...
# 3                              [Carlson, J., Adams, M.]
# 4     [McInnes, K., Hemer, M., O'Grady, J., Hoeke, R...
# ...                                                 ...
# 4238              [Spicer, P., MacCready, P., Yang, Z.]
# 4239  [Benjamins, S., Williamson, B., Billing, S-L.,...
# 4240  [Lawrence, J., Speirs, D., Heath, M., Fujii, T...
# 4241  [Ouro, P., Fernandez, R, Armstrong, A., Brooks...
# 4242  [Hunter, C., Lee, E., Wood, W., Marsh, A., Fis...
#
#                                            organization originationDate  \
# 0     [Hellenic Centre for Marine Research (HCMR), N...      2017-09-29
# 1                                    [BioPower Systems]      2016-02-09
# 2     [Marine Sensing and Acoustic Technologies (Mar...      2020-01-10
# 3             [Queens University, Dalhousie University]      2020-03-01
# 4     [Commonwealth Scientific and Industrial Resear...      2018-02-14
# ...                                                 ...             ...
# 4238  [Pacific Northwest National Laboratory (PNNL),...      2024-05-01
# 4239  [University of the Highlands and Islands (UHI)...      2024-07-01
# 4240  [Heriot-Watt University, University of Strathc...      2024-05-06
# 4241  [University of Manchester, Cardiff University,...      2024-05-16
# 4242   [Blue Economy Cooperative Research Centre (CRC)]      2024-04-01
#
#                                                 spatial  \
# 0                                                    []
# 1     {'coordinates': ['-38.398417000000', '142.1726...
# 2     {'coordinates': ['36.972554000000', '-7.870570...
# 3     {'coordinates': ['45.166454000000', '-63.06410...
# 4     {'coordinates': ['-32.203436000000', '115.6775...
# ...                                                 ...
# 4238  {'coordinates': ['48.307502000000', '-123.0106...
# 4239                                                 []
# 4240  {'coordinates': ['56.203910000000', '2.5678100...
# 4241                                                 []
# 4242                                                 []
#
#                       technologyType  \
# 0                                 []
# 1                             [Wave]
# 2           [Current, Current/Tidal]
# 3           [Current, Current/Tidal]
# 4                             [Wave]
# ...                              ...
# 4238        [Current, Current/Tidal]
# 4239                              []
# 4240                              []
# 4241  [Current, Current/Tidal, Wave]
# 4242                              []
#
#                                                    tags         modifiedDate  \
# 0                       [Environment, Human Dimensions]  2024-01-22 09:24:45
# 1        [Environment, Environmental Impact Assessment]  2024-01-22 09:24:45
# 2                                  [Environment, Noise]  2024-01-22 09:24:45
# 3       [Environment, Human Dimensions, Legal & Policy]  2024-01-22 09:24:45
# 4     [Environment, Physical Environment, Changes in...  2024-01-22 09:24:45
# ...                                                 ...                  ...
# 4238  [Environment, Physical Environment, Changes in...  2024-05-21 11:34:06
# 4239  [Environment, Birds, Fish, Marine Mammals, Phy...  2024-05-28 10:55:38
# 4240                    [Environment, Fish, Attraction]  2024-05-28 11:22:54
# 4241  [Environment, Birds, Fish, Marine Mammals, Cet...  2024-05-30 11:47:01
# 4242  [Environment, Human Dimensions, Environmental ...  2024-05-31 07:07:53
#
#      signatureProject                                         attachment  \
# 0                  []                                                 []
# 1                  []  [https://tethys.pnnl.gov/sites/default/files/p...
# 2                  []                                                 []
# 3                  []                                                 []
# 4                  []  [https://tethys.pnnl.gov/sites/default/files/p...
# ...               ...                                                ...
# 4238               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4239               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4240               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4241               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4242               []  [https://tethys.pnnl.gov/sites/default/files/p...
#
#      originationDate2
# 0          2017-09-29
# 1          2016-02-09
# 2          2020-01-10
# 3          2020-03-01
# 4          2018-02-14
# ...               ...
# 4238       2024-05-01
# 4239       2024-07-01
# 4240       2024-05-06
# 4241       2024-05-16
# 4242       2024-04-01
#
# [4243 rows x 16 columns]

# %%
date_interest = pd.datetime.date(2000, 1, 1)
# Out:
# C:\Users\deca761\AppData\Local\Temp\ipykernel_21456\2715152395.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date_interest = pd.datetime.date(2000, 1, 1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 date_interest = pd.datetime.date(2000, 1, 1)
#
# TypeError: descriptor 'date' for 'datetime.datetime' objects doesn't apply to a 'int' object

# %%
import numpy as np
import datetime

date_before = np.datetime64(datetime.date(2016, 1, 19))
#df[df['newest_date_available'] < date_before]

tethys_dataframe[tethys_dataframe['originationDate2'] > date_before]
# Out:
#                                        URI  \
# 0         https://tethys.pnnl.gov/node/499
# 1         https://tethys.pnnl.gov/node/500
# 2         https://tethys.pnnl.gov/node/501
# 3         https://tethys.pnnl.gov/node/502
# 4         https://tethys.pnnl.gov/node/503
# ...                                    ...
# 4238  https://tethys.pnnl.gov/node/2078945
# 4239  https://tethys.pnnl.gov/node/2078958
# 4240  https://tethys.pnnl.gov/node/2078959
# 4241  https://tethys.pnnl.gov/node/2078965
# 4242  https://tethys.pnnl.gov/node/2078973
#
#                                       type  \
# 0     [Document, Document/Journal Article]
# 1              [Document, Document/Report]
# 2     [Document, Document/Journal Article]
# 3     [Document, Document/Journal Article]
# 4              [Document, Document/Report]
# ...                                    ...
# 4238  [Document, Document/Journal Article]
# 4239  [Document, Document/Journal Article]
# 4240  [Document, Document/Journal Article]
# 4241  [Document, Document/Journal Article]
# 4242           [Document, Document/Report]
#
#                                             landingPage  \
# 0     https://tethys.pnnl.gov/publications/marine-re...
# 1     https://tethys.pnnl.gov/publications/port-fair...
# 2     https://tethys.pnnl.gov/publications/baseline-...
# 3     https://tethys.pnnl.gov/publications/assessing...
# 4     https://tethys.pnnl.gov/publications/wave-ener...
# ...                                                 ...
# 4238  https://tethys.pnnl.gov/publications/localized...
# 4239  https://tethys.pnnl.gov/publications/potential...
# 4240  https://tethys.pnnl.gov/publications/elevated-...
# 4241  https://tethys.pnnl.gov/publications/environme...
# 4242  https://tethys.pnnl.gov/publications/cultural-...
#
#                                               sourceURL  \
# 0         https://www.mdpi.com/1996-1073/10/10/1512/htm
# 1                            http://bps.energy/projects
# 2     https://www.sciencedirect.com/science/article/...
# 3     https://www.sciencedirect.com/science/article/...
# 4     https://publications.csiro.au/rpr/pub?pid=csir...
# ...                                                 ...
# 4238  https://agupubs.onlinelibrary.wiley.com/doi/fu...
# 4239  https://www.sciencedirect.com/science/article/...
# 4240  https://journals.plos.org/plosone/article?id=1...
# 4241  https://iopscience.iop.org/article/10.1088/174...
# 4242  https://blueeconomycrc.com.au/project/cultural...
#
#                                                   title  \
# 0     Marine Renewable Energy in the Mediterranean S...
# 1     The Port Fairy Pilot Wave Energy Project Envir...
# 2     Baseline assessment of underwater noise in the...
# 3     Assessing the consistency of in-stream tidal e...
# 4     Wave Energy Deployments Physical Impact Guidel...
# ...                                                 ...
# 4238  Localized Tidal Energy Extraction in Puget Sou...
# 4239  Potential environmental impacts of floating so...
# 4240  Elevated fish densities extend kilometres from...
# 4241  Environmental impacts from large scale offshor...
# 4242  Cultural Licence to Operate in the Blue Econom...
#
#                                             description  \
# 0     In this work, an extended overview of the mari...
# 1     This Environmental Management Plan (EMP) detai...
# 2     The Ria Formosa is a sheltered large coastal l...
# 3     The provincial government of Nova Scotia, Cana...
# 4     Australia’s wave energy resource has been asse...
# ...                                                 ...
# 4238  Harvesting energy via tidal stream turbines is...
# 4239  The use of floating photovoltaic systems in fr...
# 4240  Thousands of offshore oil and gas platforms ha...
# 4241  The urgency to mitigate the effects of climate...
# 4242  In an era of heightened awareness of environme...
#
#                                                  author  \
# 0     [Soukissian, T., Denaxa, D., Karathanasi, F., ...
# 1                                    [BioPower Systems]
# 2     [Soares, C., Pacheco, A., Zabel, F., González-...
# 3                              [Carlson, J., Adams, M.]
# 4     [McInnes, K., Hemer, M., O'Grady, J., Hoeke, R...
# ...                                                 ...
# 4238              [Spicer, P., MacCready, P., Yang, Z.]
# 4239  [Benjamins, S., Williamson, B., Billing, S-L.,...
# 4240  [Lawrence, J., Speirs, D., Heath, M., Fujii, T...
# 4241  [Ouro, P., Fernandez, R, Armstrong, A., Brooks...
# 4242  [Hunter, C., Lee, E., Wood, W., Marsh, A., Fis...
#
#                                            organization originationDate  \
# 0     [Hellenic Centre for Marine Research (HCMR), N...      2017-09-29
# 1                                    [BioPower Systems]      2016-02-09
# 2     [Marine Sensing and Acoustic Technologies (Mar...      2020-01-10
# 3             [Queens University, Dalhousie University]      2020-03-01
# 4     [Commonwealth Scientific and Industrial Resear...      2018-02-14
# ...                                                 ...             ...
# 4238  [Pacific Northwest National Laboratory (PNNL),...      2024-05-01
# 4239  [University of the Highlands and Islands (UHI)...      2024-07-01
# 4240  [Heriot-Watt University, University of Strathc...      2024-05-06
# 4241  [University of Manchester, Cardiff University,...      2024-05-16
# 4242   [Blue Economy Cooperative Research Centre (CRC)]      2024-04-01
#
#                                                 spatial  \
# 0                                                    []
# 1     {'coordinates': ['-38.398417000000', '142.1726...
# 2     {'coordinates': ['36.972554000000', '-7.870570...
# 3     {'coordinates': ['45.166454000000', '-63.06410...
# 4     {'coordinates': ['-32.203436000000', '115.6775...
# ...                                                 ...
# 4238  {'coordinates': ['48.307502000000', '-123.0106...
# 4239                                                 []
# 4240  {'coordinates': ['56.203910000000', '2.5678100...
# 4241                                                 []
# 4242                                                 []
#
#                       technologyType  \
# 0                                 []
# 1                             [Wave]
# 2           [Current, Current/Tidal]
# 3           [Current, Current/Tidal]
# 4                             [Wave]
# ...                              ...
# 4238        [Current, Current/Tidal]
# 4239                              []
# 4240                              []
# 4241  [Current, Current/Tidal, Wave]
# 4242                              []
#
#                                                    tags         modifiedDate  \
# 0                       [Environment, Human Dimensions]  2024-01-22 09:24:45
# 1        [Environment, Environmental Impact Assessment]  2024-01-22 09:24:45
# 2                                  [Environment, Noise]  2024-01-22 09:24:45
# 3       [Environment, Human Dimensions, Legal & Policy]  2024-01-22 09:24:45
# 4     [Environment, Physical Environment, Changes in...  2024-01-22 09:24:45
# ...                                                 ...                  ...
# 4238  [Environment, Physical Environment, Changes in...  2024-05-21 11:34:06
# 4239  [Environment, Birds, Fish, Marine Mammals, Phy...  2024-05-28 10:55:38
# 4240                    [Environment, Fish, Attraction]  2024-05-28 11:22:54
# 4241  [Environment, Birds, Fish, Marine Mammals, Cet...  2024-05-30 11:47:01
# 4242  [Environment, Human Dimensions, Environmental ...  2024-05-31 07:07:53
#
#      signatureProject                                         attachment  \
# 0                  []                                                 []
# 1                  []  [https://tethys.pnnl.gov/sites/default/files/p...
# 2                  []                                                 []
# 3                  []                                                 []
# 4                  []  [https://tethys.pnnl.gov/sites/default/files/p...
# ...               ...                                                ...
# 4238               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4239               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4240               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4241               []  [https://tethys.pnnl.gov/sites/default/files/p...
# 4242               []  [https://tethys.pnnl.gov/sites/default/files/p...
#
#      originationDate2
# 0          2017-09-29
# 1          2016-02-09
# 2          2020-01-10
# 3          2020-03-01
# 4          2018-02-14
# ...               ...
# 4238       2024-05-01
# 4239       2024-07-01
# 4240       2024-05-06
# 4241       2024-05-16
# 4242       2024-04-01
#
# [2105 rows x 16 columns]

# %%
help(datetime.date)
# Out:
# Help on class date in module datetime:
#
# class date(builtins.object)
#  |  date(year, month, day) --> date object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      Formats self with strftime.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __reduce__(...)
#  |      __reduce__() -> (cls, state)
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  ctime(...)
#  |      Return ctime() style string.
#  |
#  |  isocalendar(...)
#  |      Return a named tuple containing ISO year, week number, and weekday.
#  |
#  |  isoformat(...)
#  |      Return string in ISO 8601 format, YYYY-MM-DD.
#  |
#  |  isoweekday(...)
#  |      Return the day of the week represented by the date.
#  |      Monday == 1 ... Sunday == 7
#  |
#  |  replace(...)
#  |      Return date with new specified fields.
#  |
#  |  strftime(...)
#  |      format -> strftime() style string.
#  |
#  |  timetuple(...)
#  |      Return time tuple, compatible with time.localtime().
#  |
#  |  toordinal(...)
#  |      Return proleptic Gregorian ordinal.  January 1 of year 1 is day 1.
#  |
#  |  weekday(...)
#  |      Return the day of the week represented by the date.
#  |      Monday == 0 ... Sunday == 6
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  fromisocalendar(...) from builtins.type
#  |      int, int, int -> Construct a date from the ISO year, week number and weekday.
#  |
#  |      This is the inverse of the date.isocalendar() function
#  |
#  |  fromisoformat(...) from builtins.type
#  |      str -> Construct a date from a string in ISO 8601 format.
#  |
#  |  fromordinal(...) from builtins.type
#  |      int -> date corresponding to a proleptic Gregorian ordinal.
#  |
#  |  fromtimestamp(timestamp, /) from builtins.type
#  |      Create a date from a POSIX timestamp.
#  |
#  |      The timestamp is a number, e.g. created via time.time(), that is interpreted
#  |      as local time.
#  |
#  |  today(...) from builtins.type
#  |      Current date or datetime:  same as self.__class__.fromtimestamp(time.time()).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  day
#  |
#  |  month
#  |
#  |  year
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  max = datetime.date(9999, 12, 31)
#  |
#  |  min = datetime.date(1, 1, 1)
#  |
#  |  resolution = datetime.timedelta(days=1)
